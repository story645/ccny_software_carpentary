# %% [markdown]
# ![bad models](https://pbs.twimg.com/media/B2X3Ls9IgAAW9J-.jpg:large "Cairo Image")
# Models can't be built from entire dataset because model will tend to overfit; therefore data is often split into a **training** dataset on which the model is fit, and a **testing** dataset it is applied to/used on. This lesson is on a subset of Titanic data used to train a model.
#
# Data for this notebook: [train.csv](https://drive.google.com/file/d/0B_T4ui-li2LOMDRyUGxTZGNFNjg/view?usp=sharing)

# %% [raw]
# #various ways to import
# import pandas as pd # renames the pandas library to pd inside the code
# from pandas import Series  #imports just the Series object from pandas
# from pandas import * #imports everything

# %%
import pandas as pd
#check which version of pandas is being used
pd.__version__
# Out:
# '0.16.2'

# %%
pd.read_csv?

# %%
#load in the train data as a dataframe (spreadsheet)
pd.read_csv("data/train.csv")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
#above not saved, so instead assign to a variable
train = pd.read_csv('./data/train.csv')

# %%
#view the first 5 rows of the data
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#view the last 5 rows
train.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex  Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male   27      0      0      211536  13.00   NaN        S
# 887  female   19      0      0      112053  30.00   B42        S
# 888  female  NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male   26      0      0      111369  30.00  C148        C
# 890    male   32      0      0      370376   7.75   NaN        Q

# %%
#can specify the number
train.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
#lets look at dimensions
#since pandas uses numpy, use a numpy function
train.shape
# Out:
# (891, 12)

# %%
#get a columnwise summary
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 90.5+ KB

# %%
#to just get the datatype of each column
train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
#select just 1 column and restrict to first 5
train['Age'].head()
#try to avoid spaces in column names
# Out:
# 0    22
# 1    38
# 2    26
# 3    35
# 4    35
# Name: Age, dtype: float64

# %%
#can also use dot notation, but not recommended
train.Age.head()
# Out:
# 0    22
# 1    38
# 2    26
# 3    35
# 4    35
# Name: Age, dtype: float64

# %%
#to see how long an instruction takes, use ipython magic: %time
# %time train['Age'].head()
# Out:
# Wall time: 0 ns
# 0    22
# 1    38
# 2    26
# 3    35
# 4    35
# Name: Age, dtype: float64

# %%
# %time train.Age.head()
# Out:
# Wall time: 0 ns
# 0    22
# 1    38
# 2    26
# 3    35
# 4    35
# Name: Age, dtype: float64

# %% [markdown]
# # Indexing #

# %%
#multiple columns?
train['Age','Pclass']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-26477953d7df> in <module>()
#       1 #multiple columns?
# ----> 2 train['Age','Pclass']
#
# C:\Users\story645\Anaconda\envs\science\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    1795             return self._getitem_multilevel(key)
#    1796         else:
# -> 1797             return self._getitem_column(key)
#    1798
#    1799     def _getitem_column(self, key):
#
# C:\Users\story645\Anaconda\envs\science\lib\site-packages\pandas\core\frame.pyc in _getitem_column(self, key)
#    1802         # get column
#    1803         if self.columns.is_unique:
# -> 1804             return self._get_item_cache(key)
#    1805
#    1806         # duplicate columns & possible reduce dimensionaility
#
# ...

# %%
#can't do that, because it things Age and Pclass are one thing
#Pass in a list of columns you want instead
train[['Age','Pclass']].head()
# Out:
#    Age  Pclass
# 0   22       3
# 1   38       1
# 2   26       3
# 3   35       1
# 4   35       3

# %%
#order dictates how it's displayed
train[['Pclass', 'Age']].head()
# Out:
#    Pclass  Age
# 0       3   22
# 1       1   38
# 2       3   26
# 3       1   35
# 4       3   35

# %%
#subset arbitrary rows
train[['Pclass','Age']][0:3] #indexes based on row indexes-first column in table
# Out:
#    Pclass  Age
# 0       3   22
# 1       1   38
# 2       3   26

# %%
#0 can be omitted
train[['Pclass','Age']][:3]
# Out:
#    Pclass  Age
# 0       3   22
# 1       1   38
# 2       3   26

# %%
"""train2 is the same thing as train and so any changes to train2 also change train
(object assignement is by reference rather than value, so train2 points to same place in memory as train
"""
train2=train

# %%
#COPY IS EXPLICIT
train1 = train.copy()

# %%
train1['Age'][0:3] = 0
# Out:
# C:\Users\story645\Anaconda\envs\science\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
train1['Age'][0:3] #changed these values
# Out:
# 0    0
# 1    0
# 2    0
# Name: Age, dtype: float64

# %%
train['Age'][0:3] #original untouched
# Out:
# 0    22
# 1    38
# 2    26
# Name: Age, dtype: float64

# %%
#use whos to see which variables are currently in the workspace
#must be in its own cell

# %%
whos
# Out:
# Variable   Type         Data/Info
# ---------------------------------
# pd         module       <module 'pandas' from 'C:<...>ges\pandas\__init__.pyc'>
# train      DataFrame         PassengerId  Survive<...>\n[891 rows x 12 columns]
# train1     DataFrame         PassengerId  Survive<...>\n[891 rows x 12 columns]
# train2     DataFrame         PassengerId  Survive<...>\n[891 rows x 12 columns]

# %%
#use index based selections->under the hood it's more efficient
#doesn't copy the data for the subset, is what's called a view on the data
train.loc[:,["Age",'Pclass']]
# Out:
#      Age  Pclass
# 0     22       3
# 1     38       1
# 2     26       3
# 3     35       1
# 4     35       3
# 5    NaN       3
# 6     54       1
# 7      2       3
# 8     27       3
# 9     14       2
# 10     4       3
# 11    58       1
# 12    20       3
# 13    39       3
# 14    14       3
# 15    55       2
# 16     2       3
# 17   NaN       2
# 18    31       3
# 19   NaN       3
# 20    35       2
# 21    34       2
# 22    15       3
# 23    28       1
# 24     8       3
# 25    38       3
# 26   NaN       3
# 27    19       1
# 28   NaN       3
# 29   NaN       3
# ..   ...     ...
# 861   21       2
# 862   48       1
# 863  NaN       3
# 864   24       2
# 865   42       2
# 866   27       2
# 867   31       1
# 868  NaN       3
# 869    4       3
# 870   26       3
# 871   47       1
# 872   33       1
# 873   47       3
# 874   28       2
# 875   15       3
# 876   20       3
# 877   19       3
# 878  NaN       3
# 879   56       1
# 880   25       2
# ...

# %%
#can be used to grab multiple columns, everything from Pclass to age
train.loc[:,'Pclass':'Age']
# Out:
#      Pclass                                               Name     Sex  Age
# 0         3                            Braund, Mr. Owen Harris    male   22
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38
# 2         3                             Heikkinen, Miss. Laina  female   26
# 3         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35
# 4         3                           Allen, Mr. William Henry    male   35
# 5         3                                   Moran, Mr. James    male  NaN
# 6         1                            McCarthy, Mr. Timothy J    male   54
# 7         3                     Palsson, Master. Gosta Leonard    male    2
# 8         3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female   27
# 9         2                Nasser, Mrs. Nicholas (Adele Achem)  female   14
# 10        3                    Sandstrom, Miss. Marguerite Rut  female    4
# ...

# %%
#view column names
train.columns
# Out:
# Index([u'PassengerId', u'Survived', u'Pclass', u'Name', u'Sex', u'Age',
#        u'SibSp', u'Parch', u'Ticket', u'Fare', u'Cabin', u'Embarked'],
#       dtype='object')

# %%
#pure numerical indexing 
train.iloc[[0,4,10],:]
# Out:
#     PassengerId  Survived  Pclass                             Name     Sex  \
# 0             1         0       3          Braund, Mr. Owen Harris    male
# 4             5         0       3         Allen, Mr. William Henry    male
# 10           11         1       3  Sandstrom, Miss. Marguerite Rut  female
#
#     Age  SibSp  Parch     Ticket   Fare Cabin Embarked
# 0    22      1      0  A/5 21171   7.25   NaN        S
# 4    35      0      0     373450   8.05   NaN        S
# 10    4      1      1    PP 9549  16.70    G6        S

# %%
import numpy as np #rename numpy as np
#use this to take non-sequential slices
train.iloc[np.r_[0,4:10,12],:]
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 12           13         0       3
#
#                                                  Name     Sex  Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male   22      1
# 4                            Allen, Mr. William Henry    male   35      0
# 5                                    Moran, Mr. James    male  NaN      0
# 6                             McCarthy, Mr. Timothy J    male   54      0
# 7                      Palsson, Master. Gosta Leonard    male    2      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female   27      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female   14      1
# ...

# %% [markdown]
# # Summary Statistics#

# %%
#get # of occurances of each age in the dataset
train['Age'].value_counts()#handles missing data 'cause data is coded missing in this table
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 28.00    25
# 30.00    25
# 19.00    25
# 21.00    24
# 25.00    23
# 36.00    22
# 29.00    20
# 32.00    18
# 35.00    18
# 27.00    18
# 26.00    18
# 16.00    17
# 31.00    17
# 33.00    15
# 20.00    15
# 34.00    15
# 23.00    15
# 39.00    14
# 17.00    13
# 42.00    13
# 40.00    13
# 45.00    12
# 38.00    11
# 4.00     10
# 50.00    10
# 2.00     10
# 47.00     9
#          ..
# 40.50     2
# 10.00     2
# 13.00     2
# 45.50     2
# 64.00     2
# 71.00     2
# 70.00     2
# 30.50     2
# 0.83      2
# 63.00     2
# 59.00     2
# 57.00     2
# 55.00     2
# 0.75      2
# 0.42      1
# 53.00     1
# 70.50     1
# 14.50     1
# 0.92      1
# 74.00     1
# 36.50     1
# 80.00     1
# 12.00     1
# 55.50     1
# 34.50     1
# 24.50     1
# 66.00     1
# 23.50     1
# 0.67      1
# 20.50     1
# dtype: int64

# %%
#get summary statistics
print train['Age'].min()
print train['Age'].mean()
print train['Age'].max()
# Out:
# 0.42
# 29.6991176471
# 80.0

# %%
#get all of them together
train['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
#get information for entire dataset
train.describe() #omits string columns
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train.describe(include=['object'])#include the string values too
#string is an object datatype, include says which datatypes to include
# Out:
#                              Name   Sex    Ticket        Cabin Embarked
# count                         891   891       891          204      889
# unique                        891     2       681          147        3
# top     Graham, Mr. George Edward  male  CA. 2343  C23 C25 C27        S
# freq                            1   577         7            4      644

# %%
train.describe(include=['number']) #same as default
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train.describe(include='all') #includes everything
# Out:
#         PassengerId    Survived      Pclass                       Name   Sex  \
# count    891.000000  891.000000  891.000000                        891   891
# unique          NaN         NaN         NaN                        891     2
# top             NaN         NaN         NaN  Graham, Mr. George Edward  male
# freq            NaN         NaN         NaN                          1   577
# mean     446.000000    0.383838    2.308642                        NaN   NaN
# std      257.353842    0.486592    0.836071                        NaN   NaN
# min        1.000000    0.000000    1.000000                        NaN   NaN
# 25%      223.500000    0.000000    2.000000                        NaN   NaN
# 50%      446.000000    0.000000    3.000000                        NaN   NaN
# 75%      668.500000    1.000000    3.000000                        NaN   NaN
# max      891.000000    1.000000    3.000000                        NaN   NaN
#
# ...

# %% [markdown]
# # Conditional Indexing #

# %%
#boolean indexing
train['Age'][train['Age']>60] #take every row of the age column where the age is greater than 60
# Out:
# 33     66.0
# 54     65.0
# 96     71.0
# 116    70.5
# 170    61.0
# 252    62.0
# 275    63.0
# 280    65.0
# 326    61.0
# 438    64.0
# 456    65.0
# 483    63.0
# 493    71.0
# 545    64.0
# 555    62.0
# 570    62.0
# 625    61.0
# 630    80.0
# 672    70.0
# 745    70.0
# 829    62.0
# 851    74.0
# Name: Age, dtype: float64

# %%
train['Name'][train['Age']>60] #the name of every person over 60
# Out:
# 33                         Wheadon, Mr. Edward H
# 54                Ostby, Mr. Engelhart Cornelius
# 96                     Goldschmidt, Mr. George B
# 116                         Connors, Mr. Patrick
# 170                    Van der hoef, Mr. Wyckoff
# 252                    Stead, Mr. William Thomas
# 275            Andrews, Miss. Kornelia Theodosia
# 280                             Duane, Mr. Frank
# 326                    Nysveen, Mr. Johan Hansen
# 438                            Fortune, Mr. Mark
# 456                    Millet, Mr. Francis Davis
# 483                       Turkula, Mrs. (Hedwig)
# 493                      Artagaveytia, Mr. Ramon
# 545                 Nicholson, Mr. Arthur Ernest
# 555                           Wright, Mr. George
# 570                           Harris, Mr. George
# 625                        Sutton, Mr. Frederick
# 630         Barkworth, Mr. Algernon Henry Wilson
# 672                  Mitchell, Mr. Henry Michael
# ...

# %%
train['Name'][train['Age']!=60] #everyone who's not 60
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
# 5                                       Moran, Mr. James
# 6                                McCarthy, Mr. Timothy J
# 7                         Palsson, Master. Gosta Leonard
# 8      Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                    Nasser, Mrs. Nicholas (Adele Achem)
# 10                       Sandstrom, Miss. Marguerite Rut
# 11                              Bonnell, Miss. Elizabeth
# 12                        Saundercock, Mr. William Henry
# 13                           Andersson, Mr. Anders Johan
# 14                  Vestrom, Miss. Hulda Amanda Adolfina
# 15                      Hewlett, Mrs. (Mary D Kingcome)
# ...

# %%
train['Name'][~(train['Age']!=60)]#negate the condition age!=60, so everyone who is 60
# Out:
# 366    Warren, Mrs. Frank Manley (Anna Sophia Atkinson)
# 587                    Frolicher-Stehli, Mr. Maxmillian
# 684                   Brown, Mr. Thomas William Solomon
# 694                                     Weir, Col. John
# Name: Name, dtype: object

# %%
#combine conditions
#everyone between 60 and 75
train[(train['Age']>60)&(train['Age']<75)]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 33            34         0       2                      Wheadon, Mr. Edward H
# 54            55         0       1             Ostby, Mr. Engelhart Cornelius
# 96            97         0       1                  Goldschmidt, Mr. George B
# 116          117         0       3                       Connors, Mr. Patrick
# 170          171         0       1                  Van der hoef, Mr. Wyckoff
# 252          253         0       1                  Stead, Mr. William Thomas
# 275          276         1       1          Andrews, Miss. Kornelia Theodosia
# 280          281         0       3                           Duane, Mr. Frank
# 326          327         0       3                  Nysveen, Mr. Johan Hansen
# 438          439         0       1                          Fortune, Mr. Mark
# 456          457         0       1                  Millet, Mr. Francis Davis
# ...

# %%
#lets look at extreme populations: under 2 or over 75

train[(train['Age']>75)|(train['Age']<2)]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 78            79         1       2         Caldwell, Master. Alden Gates
# 164          165         0       3          Panula, Master. Eino Viljami
# 172          173         1       3          Johnson, Miss. Eleanor Ileen
# 183          184         1       2             Becker, Master. Richard F
# 305          306         1       1        Allison, Master. Hudson Trevor
# 381          382         1       3           Nakid, Miss. Maria ("Mary")
# 386          387         0       3       Goodwin, Master. Sidney Leonard
# 469          470         1       3         Baclini, Miss. Helene Barbara
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 644          645         1       3                Baclini, Miss. Eugenie
# 755          756         1       2             Hamalainen, Master. Viljo
# 788          789         1       3            Dean, Master. Bertram Vere
# ...

# %% [markdown]
# Programming Challenge
# ===========
# Select passangers that meet these criteria:
# * in 3rd class
# * under age 10
# * female

# %%
train[(train['Pclass']==3)&(train['Age']<10) & (train['Sex']=='female')]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 10            11         1       3       Sandstrom, Miss. Marguerite Rut
# 24            25         0       3         Palsson, Miss. Torborg Danira
# 119          120         0       3     Andersson, Miss. Ellis Anna Maria
# 147          148         0       3      Ford, Miss. Robina Maggie "Ruby"
# 172          173         1       3          Johnson, Miss. Eleanor Ileen
# 184          185         1       3   Kink-Heilmann, Miss. Luise Gretchen
# 205          206         0       3            Strom, Miss. Telma Matilda
# 233          234         1       3        Asplund, Miss. Lillian Gertrud
# 374          375         0       3            Palsson, Miss. Stina Viola
# 381          382         1       3           Nakid, Miss. Maria ("Mary")
# 448          449         1       3        Baclini, Miss. Marie Catherine
# 469          470         1       3         Baclini, Miss. Helene Barbara
# ...

# %% [markdown]
# # Function based filtering#

# %%
#see if ticket matches that that string 
train['Ticket'].str.match('PC 17599') #boolean array of matches
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 861    False
# 862    False
# 863    False
# 864    False
# 865    False
# 866    False
# 867    False
# 868    False
# 869    False
# 870    False
# 871    False
# 872    False
# 873    False
# 874    False
# 875    False
# 876    False
# 877    False
# 878    False
# 879    False
# 880    False
# 881    False
# 882    False
# 883    False
# 884    False
# 885    False
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Ticket, dtype: bool

# %%
#filter train based on that criteria
train[train['Ticket'].str.match('PC 17599')]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
#
#                                                 Name     Sex  Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
#
#    Parch    Ticket     Fare Cabin Embarked
# 1      0  PC 17599  71.2833   C85        C

# %%
#filter any people who match any in this set of criteria
train[train['Ticket'].isin(['113803'])]
# Out:
#      PassengerId  Survived  Pclass  \
# 3              4         1       1
# 137          138         0       1
#
#                                              Name     Sex  Age  SibSp  Parch  \
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1      0
# 137                   Futrelle, Mr. Jacques Heath    male   37      1      0
#
#      Ticket  Fare Cabin Embarked
# 3    113803  53.1  C123        S
# 137  113803  53.1  C123        S

# %%
#filter ages of anyone in any of the groups 20, 30, 40
train[train['Age'].isin([20, 30, 40])]
# Out:
#      PassengerId  Survived  Pclass  \
# 12            13         0       3
# 30            31         0       1
# 40            41         0       3
# 79            80         1       3
# 91            92         0       3
# 113          114         0       3
# 131          132         0       3
# 157          158         0       3
# 161          162         1       2
# 178          179         0       2
# 188          189         0       3
# 209          210         1       1
# 213          214         0       2
# 219          220         0       2
# 244          245         0       3
# 253          254         0       3
# 257          258         1       1
# 263          264         0       1
# 286          287         1       3
# 308          309         0       2
# 309          310         1       1
# 319          320         1       1
# 322          323         1       2
# 346          347         1       2
# 360          361         0       3
# ...

# %%
#find anyone whose name contains John
train[train['Name'].str.contains('John')]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 8              9         1       3
# 41            42         0       2
# 45            46         0       3
# 98            99         1       2
# 112          113         0       3
# 117          118         0       2
# 160          161         0       3
# 162          163         0       3
# 165          166         1       3
# 168          169         0       1
# 172          173         1       3
# 188          189         0       3
# 212          213         0       3
# 226          227         1       2
# 227          228         0       3
# 302          303         0       3
# 324          325         0       3
# 328          329         1       3
# 401          402         0       3
# 418          419         0       2
# 467          468         0       1
# 527          528         0       1
# 548          549         0       3
# 549          550         1       2
# ...

# %%
train['Age'].order() #sort in ascending order
# Out:
# 803    0.42
# 755    0.67
# 644    0.75
# 469    0.75
# 78     0.83
# 831    0.83
# 305    0.92
# 827    1.00
# 381    1.00
# 164    1.00
# 183    1.00
# 386    1.00
# 172    1.00
# 788    1.00
# 642    2.00
# 7      2.00
# 530    2.00
# 297    2.00
# 824    2.00
# 205    2.00
# 119    2.00
# 340    2.00
# 479    2.00
# 16     2.00
# 348    3.00
# 407    3.00
# 374    3.00
# 261    3.00
# 43     3.00
# 193    3.00
#        ...
# 718     NaN
# 727     NaN
# 732     NaN
# 738     NaN
# 739     NaN
# 740     NaN
# 760     NaN
# 766     NaN
# 768     NaN
# 773     NaN
# 776     NaN
# 778     NaN
# 783     NaN
# 790     NaN
# 792     NaN
# 793     NaN
# 815     NaN
# 825     NaN
# 826     NaN
# 828     NaN
# 832     NaN
# 837     NaN
# 839     NaN
# 846     NaN
# 849     NaN
# 859     NaN
# 863     NaN
# 868     NaN
# 878     NaN
# 888     NaN
# Name: Age, dtype: float64

# %%
train['Age'].order(ascending=False)#sort in reverse order
# Out:
# 630    80.0
# 851    74.0
# 96     71.0
# 493    71.0
# 116    70.5
# 745    70.0
# 672    70.0
# 33     66.0
# 456    65.0
# 280    65.0
# 54     65.0
# 545    64.0
# 438    64.0
# 483    63.0
# 275    63.0
# 555    62.0
# 570    62.0
# 829    62.0
# 252    62.0
# 625    61.0
# 326    61.0
# 170    61.0
# 366    60.0
# 587    60.0
# 684    60.0
# 694    60.0
# 94     59.0
# 232    59.0
# 268    58.0
# 487    58.0
#        ...
# 718     NaN
# 727     NaN
# 732     NaN
# 738     NaN
# 739     NaN
# 740     NaN
# 760     NaN
# 766     NaN
# 768     NaN
# 773     NaN
# 776     NaN
# 778     NaN
# 783     NaN
# 790     NaN
# 792     NaN
# 793     NaN
# 815     NaN
# 825     NaN
# 826     NaN
# 828     NaN
# 832     NaN
# 837     NaN
# 839     NaN
# 846     NaN
# 849     NaN
# 859     NaN
# 863     NaN
# 868     NaN
# 878     NaN
# 888     NaN
# Name: Age, dtype: float64

# %%
#sort by columns
#sorted by class, then by age
train.sort_index(by=['Pclass', 'Age']).head()
# Out:
#      PassengerId  Survived  Pclass                                 Name  \
# 305          306         1       1       Allison, Master. Hudson Trevor
# 297          298         0       1         Allison, Miss. Helen Loraine
# 445          446         1       1            Dodge, Master. Washington
# 802          803         1       1  Carter, Master. William Thornton II
# 435          436         1       1            Carter, Miss. Lucile Polk
#
#         Sex    Age  SibSp  Parch  Ticket      Fare    Cabin Embarked
# 305    male   0.92      1      2  113781  151.5500  C22 C26        S
# 297  female   2.00      1      2  113781  151.5500  C22 C26        S
# 445    male   4.00      0      2   33638   81.8583      A34        S
# 802    male  11.00      1      2  113760  120.0000  B96 B98        S
# 435  female  14.00      1      2  113760  120.0000  B96 B98        S

# %%
train.sort_index(by=['Pclass', 'Age'], ascending=[False, False]).head()#sort by highest to lowest
# Out:
#      PassengerId  Survived  Pclass                       Name     Sex   Age  \
# 851          852         0       3        Svensson, Mr. Johan    male  74.0
# 116          117         0       3       Connors, Mr. Patrick    male  70.5
# 280          281         0       3           Duane, Mr. Frank    male  65.0
# 483          484         1       3     Turkula, Mrs. (Hedwig)  female  63.0
# 326          327         0       3  Nysveen, Mr. Johan Hansen    male  61.0
#
#      SibSp  Parch  Ticket    Fare Cabin Embarked
# 851      0      0  347060  7.7750   NaN        S
# 116      0      0  370369  7.7500   NaN        Q
# 280      0      0  336439  7.7500   NaN        Q
# 483      0      0    4134  9.5875   NaN        S
# 326      0      0  345364  6.2375   NaN        S

# %%
# True and false can be represented as numbers
# False = 0
# True = 1
train.sort_index(by=['Pclass', 'Age'], ascending=[0,0]).head()
# Out:
#      PassengerId  Survived  Pclass                       Name     Sex   Age  \
# 851          852         0       3        Svensson, Mr. Johan    male  74.0
# 116          117         0       3       Connors, Mr. Patrick    male  70.5
# 280          281         0       3           Duane, Mr. Frank    male  65.0
# 483          484         1       3     Turkula, Mrs. (Hedwig)  female  63.0
# 326          327         0       3  Nysveen, Mr. Johan Hansen    male  61.0
#
#      SibSp  Parch  Ticket    Fare Cabin Embarked
# 851      0      0  347060  7.7750   NaN        S
# 116      0      0  370369  7.7500   NaN        Q
# 280      0      0  336439  7.7500   NaN        Q
# 483      0      0    4134  9.5875   NaN        S
# 326      0      0  345364  6.2375   NaN        S

# %% [markdown]
# # Missing Values #

# %%
#Passengers whose age data is missing
train[train['Age'].isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %%
#copy data
train2 = train.copy()

# %%
#assign the value 9999 to any missing (null) data
train2['Age'] = train['Age'].fillna(9999)

# %%
train2['Age'].order(ascending=False)
# Out:
# 557    9999.00
# 573    9999.00
# 547    9999.00
# 552    9999.00
# 560    9999.00
# 563    9999.00
# 564    9999.00
# 568    9999.00
# 109    9999.00
# 601    9999.00
# 578    9999.00
# 584    9999.00
# 107    9999.00
# 589    9999.00
# 593    9999.00
# 596    9999.00
# 121    9999.00
# 538    9999.00
# 126    9999.00
# 533    9999.00
# 531    9999.00
# 128    9999.00
# 527    9999.00
# 524    9999.00
# 522    9999.00
# 517    9999.00
# 511    9999.00
# 507    9999.00
# 502    9999.00
# 497    9999.00
#         ...
# 407       3.00
# 261       3.00
# 374       3.00
# 43        3.00
# 348       3.00
# 193       3.00
# 530       2.00
# 642       2.00
# 205       2.00
# 119       2.00
# 7         2.00
# 297       2.00
# 340       2.00
# 16        2.00
# 479       2.00
# 824       2.00
# 788       1.00
# 183       1.00
# 381       1.00
# 386       1.00
# 172       1.00
# 827       1.00
# 164       1.00
# 305       0.92
# 78        0.83
# 831       0.83
# 469       0.75
# 644       0.75
# ...

# %%
train2['Age'][train2['Age']==9999]=np.nan
# Out:
# C:\Users\story645\Anaconda\envs\science\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
train2 = train.copy()
train2['Age'].fillna(9999); train2['Age'].order(ascending=False) #can use semi colons to put two things on same line
# Out:
# 630    80.0
# 851    74.0
# 96     71.0
# 493    71.0
# 116    70.5
# 745    70.0
# 672    70.0
# 33     66.0
# 456    65.0
# 280    65.0
# 54     65.0
# 545    64.0
# 438    64.0
# 483    63.0
# 275    63.0
# 555    62.0
# 570    62.0
# 829    62.0
# 252    62.0
# 625    61.0
# 326    61.0
# 170    61.0
# 366    60.0
# 587    60.0
# 684    60.0
# 694    60.0
# 94     59.0
# 232    59.0
# 268    58.0
# 487    58.0
#        ...
# 718     NaN
# 727     NaN
# 732     NaN
# 738     NaN
# 739     NaN
# 740     NaN
# 760     NaN
# 766     NaN
# 768     NaN
# 773     NaN
# 776     NaN
# 778     NaN
# 783     NaN
# 790     NaN
# 792     NaN
# 793     NaN
# 815     NaN
# 825     NaN
# 826     NaN
# 828     NaN
# 832     NaN
# 837     NaN
# 839     NaN
# 846     NaN
# 849     NaN
# 859     NaN
# 863     NaN
# 868     NaN
# 878     NaN
# 888     NaN
# Name: Age, dtype: float64

# %%
#can use replace to replace 9999 with nan
train2['Age'].replace(9999,np.nan)
train2['Age'].order(ascending=False)
# Out:
# 630    80.0
# 851    74.0
# 96     71.0
# 493    71.0
# 116    70.5
# 745    70.0
# 672    70.0
# 33     66.0
# 456    65.0
# 280    65.0
# 54     65.0
# 545    64.0
# 438    64.0
# 483    63.0
# 275    63.0
# 555    62.0
# 570    62.0
# 829    62.0
# 252    62.0
# 625    61.0
# 326    61.0
# 170    61.0
# 366    60.0
# 587    60.0
# 684    60.0
# 694    60.0
# 94     59.0
# 232    59.0
# 268    58.0
# 487    58.0
#        ...
# 718     NaN
# 727     NaN
# 732     NaN
# 738     NaN
# 739     NaN
# 740     NaN
# 760     NaN
# 766     NaN
# 768     NaN
# 773     NaN
# 776     NaN
# 778     NaN
# 783     NaN
# 790     NaN
# 792     NaN
# 793     NaN
# 815     NaN
# 825     NaN
# 826     NaN
# 828     NaN
# 832     NaN
# 837     NaN
# 839     NaN
# 846     NaN
# 849     NaN
# 859     NaN
# 863     NaN
# 868     NaN
# 878     NaN
# 888     NaN
# Name: Age, dtype: float64

# %%
train3 = train.copy()

# %%
train3.shape
# Out:
# (891, 12)

# %%
#remove all rows in the table that have NA in any column
train3 = train3.dropna() #can take parameters to drop some column

# %%
train3.shape
# Out:
# (183, 12)

# %% [raw]
# #create a new column named Fare_to_age
# #assign it the value fare/age
# train['Fare_to_age'] = train['Fare']/train['Age']

# %%
print train['Fare_to_age'].describe()
# Out:
# count    714.000000
# mean       2.391841
# std        8.115102
# min        0.000000
# 25%        0.342403
# 50%        0.565217
# 75%        1.673857
# max      164.728261
# Name: Fare_to_age, dtype: float64

# %%
#integer division is an issue in Python 2
1/2
# Out:
# 0

# %%
#fix it with new division
from __future__ import division
print 1/2
#to get integer division under new division
print 1//2
# Out:
# 0.5
# 0

# %% [markdown]
# # Grouping #

# %%
#order the train data set by splitting by class
by_pclass = train.groupby('Pclass')

# %%
by_pclass #is a groupby object, needs to be further processed to be used

# %%
by_pclass.count() #how many of each record
# Out:
#         PassengerId  Survived  Name  Sex  Age  SibSp  Parch  Ticket  Fare  \
# Pclass
# 1               216       216   216  216  186    216    216     216   216
# 2               184       184   184  184  173    184    184     184   184
# 3               491       491   491  491  355    491    491     491   491
#
#         Cabin  Embarked  Fare_to_age
# Pclass
# 1         176       214          186
# 2          16       184          173
# 3          12       491          355

# %%
by_pclass.size()
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# dtype: int64

# %%
#lets calculate the survival rate by class
# Survived is coded 0 = death, 1 = lived
# Count counts every element that's not NaN
Survival_rate = by_pclass['Survived'].sum()/by_pclass['Survived'].count()
print Survival_rate
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %%
#shorter way to complete the survival rate
#survival = (sum of codes)/ (number of people in class) = sum/count
by_pclass['Survived'].mean()
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %%
by_pclass['Age'].mean()
# Out:
# Pclass
# 1    38.233441
# 2    29.877630
# 3    25.140620
# Name: Age, dtype: float64

# %%
by_pclass['Fare'].max()
# Out:
# Pclass
# 1    512.3292
# 2     73.5000
# 3     69.5500
# Name: Fare, dtype: float64

# %%
by_pclass['Fare'].min()
# Out:
# Pclass
# 1    0
# 2    0
# 3    0
# Name: Fare, dtype: float64

# %%
by_pclass['Fare'].describe() #all summary stats
# Out:
# Pclass
# 1       count    216.000000
#         mean      84.154687
#         std       78.380373
#         min        0.000000
#         25%       30.923950
#         50%       60.287500
#         75%       93.500000
#         max      512.329200
# 2       count    184.000000
#         mean      20.662183
#         std       13.417399
#         min        0.000000
#         25%       13.000000
#         50%       14.250000
#         75%       26.000000
#         max       73.500000
# 3       count    491.000000
#         mean      13.675550
#         std       11.778142
#         min        0.000000
#         25%        7.750000
#         50%        8.050000
#         75%       15.500000
#         max       69.550000
# dtype: float64

# %%
#splits the data into class and then by sex
#then computes the survival rate by subgroup 
train.groupby(['Pclass', 'Sex'])['Survived'].mean()
# Out:
# Pclass  Sex
# 1       female    0.968085
#         male      0.368852
# 2       female    0.921053
#         male      0.157407
# 3       female    0.500000
#         male      0.135447
# Name: Survived, dtype: float64

# %%
#prettify the table by rearranging by groups
train.groupby(['Pclass', 'Sex'])['Survived'].mean().unstack()
# Out:
# Sex       female      male
# Pclass
# 1       0.968085  0.368852
# 2       0.921053  0.157407
# 3       0.500000  0.135447

# %%
#create a pivot table to do advanced grouping
#index is what becomes the row
#agg function is how the data in each subset->(Pclass, Sex) is analyzed
#first argument is the name of the column being analyzed
train.pivot_table('Survived', index='Pclass', columns='Sex', aggfunc='mean')
# Out:
# Sex       female      male
# Pclass
# 1       0.968085  0.368852
# 2       0.921053  0.157407
# 3       0.500000  0.135447

# %%
#do multiple aggregations
#A python dictionary is {key:value} and usually used as a data structure
#instead of specifying one value to analyze at the beggining, multiple can be defined in the agg function
#the form is {column:aggregation_function}
train.pivot_table(index='Pclass', columns='Sex', aggfunc={'Survived':'sum', 'Fare':'mean'})
# Out:
#               Fare            Survived
# Sex         female       male   female male
# Pclass
# 1       106.125798  67.226127       91   45
# 2        21.970121  19.741782       70   17
# 3        16.118810  12.661633       72   47

# %%
#take the class by gender table and assign it to a variable
pivot_pclass_sex = train.pivot_table('Survived', index='Pclass', columns='Sex', aggfunc='mean')

# %%
import matplotlib.pyplot as plt #rename matplotlib.pyplot as plt
from matplotlib import style #make the graph prettier
# %matplotlib inline

#plot the table
pivot_pclass_sex.plot(kind='bar')

# %%
#make the graph prettier by using ggplot styling
style.use('ggplot')
pivot_pclass_sex.plot(kind='bar')

# %%
#don't need to specifiy style after first time 
#will use ggplot until reset
pivot_pclass_sex.plot(kind='bar')
plt.xticks(rotation=0) #fix the xtick labels by rotating them
# Out:
# (array([0, 1, 2]), <a list of 3 Text xticklabel objects>)

# %%
#make the figure bigger
pivot_pclass_sex.plot(kind='bar', figsize=(15,5))

# %%
#set the size for all figures until changed
plt.rcParams['figure.figsize'] = (10,8)
pivot_pclass_sex.plot(kind='bar')
plt.xticks(rotation=0)
# Out:
# (array([0, 1, 2]), <a list of 3 Text xticklabel objects>)

# %%
#switch to a horizontal bar
pivot_pclass_sex.plot(kind='barh')

# %%
#stacked bar plot
pivot_pclass_sex.plot(kind='barh', stacked=True)

# %%
#creates a histogram with 30 bins
train['Age'].hist(bins=30)

# %% [markdown]
# Recommended to look up
# ============
# * scatter plot
# * box plot
# * scatter matrix

# %%
#save the figure
plt.savefig("figure1.pdf")

# %%
#ipython notebook supports bash commands
ls
# Out:
#  Volume in drive C is Windows8_OS
#  Volume Serial Number is 2692-BF8D
#
#  Directory of C:\Users\story645\Desktop\ccny_software_carpentary
#
# 09/09/2015  04:02 PM    <DIR>          .
# 09/09/2015  04:02 PM    <DIR>          ..
# 09/09/2015  03:56 PM    <DIR>          .git
# 09/09/2015  01:05 PM    <DIR>          .ipynb_checkpoints
# 09/09/2015  04:01 PM           449,421 afternoon_session.ipynb
# 09/09/2015  01:33 PM    <DIR>          data
# 09/09/2015  04:02 PM             1,167 figure1.pdf
# 09/09/2015  02:26 PM         1,298,492 morning_session.ipynb
# 09/09/2015  09:44 AM    <DIR>          python-novice-inflammation-data
#                3 File(s)      1,749,080 bytes
#                6 Dir(s)  184,786,833,408 bytes free

# %% [markdown]
# ggplot
# =============
# ggplot library: http://ggplot.yhathq.com/
# Install ggplot in anaconda: conda install -c https://conda.binstar.org/bokeh ggplot

# %%
#import all the ggplot functions
from ggplot import *

# %%
#sets up a base plot that uses the train data, specifically the fare and age columns
plot1 = ggplot(train,aes('Fare', 'Age'))

# %%
#empty plot
plot1
# Out:
# <ggplot: (35022813)>

# %%
#add points
plot1 + geom_point()
# Out:
# <ggplot: (38607901)>

# %%
#add on lines
plot1 + geom_point() + geom_line()
# Out:
# <ggplot: (38607883)>

# %%
#use the black and white themes
plot1 + geom_point() + geom_line() + theme_bw()
# Out:
# <ggplot: (38299971)>
